# %% [markdown]
# # linear chain

# %%
from langchain_ollama import ChatOllama

model = ChatOllama(model="llama3")
# Out:
# /Users/bhavinp/workspace/langchain-practice/.venv/lib/python3.14/site-packages/langchain_core/_api/deprecation.py:26: UserWarning: Core Pydantic V1 functionality isn't compatible with Python 3.14 or greater.
#   from pydantic.v1.fields import FieldInfo as FieldInfoV1

# %%
from langchain_core.prompts import PromptTemplate

prompt1 = PromptTemplate(
    template="""
        generte a detailed report on {topic}
    """,
    input_variables=["topic"]
)

prompt2 = PromptTemplate(
    template="Generate a 5 pointer summary from the following text \n {text}",
    input_variables=["text"]
)

# %%
from langchain_core.output_parsers import StrOutputParser

parser = StrOutputParser()

# %%
chain = prompt1 | model | parser | prompt2 | model | parser

# %%
res = chain.invoke({"topic" : "IT sector of india"})

# %%
print(res)
# Out:
# Here is a 5-point summary of the report on the Indian IT sector:
#
# **1. Significant Contribution to Economy**: The Indian IT sector accounts for over 8% of the country's GDP and has a growth rate of around 10%, making it one of the most significant contributors to the economy.
#
# **2. Sector Overview**: The IT sector in India is comprised of three segments: IT Services, IT Products, and Business Process Outsourcing (BPO), with over 1.3 million professionals employed and over 4,500 companies operating in the country.
#
# **3. Trends Shaping the Future**: The sector is experiencing trends such as digital transformation, cybersecurity, emerging technologies like AI, blockchain, and IoT, and remote work, which will shape its future growth prospects.
#
# ...

# %% [markdown]
# # Parallel chains

# %%
# from langchain_google_genai import ChatGoogleGenerativeAI
# from dotenv import load_dotenv

# load_dotenv()

# model1 = ChatGoogleGenerativeAI(
#     model = "gemini-2.5-flash"
# )

# %%
from langchain_ollama import ChatOllama

model2 = ChatOllama(
    model = 
)
# Out:
# AIMessage(content='Hello! How can I help you today?', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019c240e-787b-7af0-864a-a6d6a0780182-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 2, 'output_tokens': 189, 'total_tokens': 191, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 180}})

# %%
from langchain_core.prompts import PromptTemplate

prompt1 = PromptTemplate(
    
)

# %%
from langchain_core.output_parsers import StrOutputParser

parser = StrOutputParser()

# %%
from langchain_core.runnables import RunnableParallel

# add parallel model calling

parallel_run_chain = RunnableParallel({
    "notes": prompt1 | model1 | parser,
    "quize": prompt2 | model2 | parser
})


# merging models

merger_chain = prompt3 | model1 | parser

chain = parallel_run_chain | merger_chain

# %%
# !pip install langchain-google-genai google-generativeai

# from langchain_google_genai import ChatGoogleGenerativeAI
# import os

# os.environ["GOOGLE_API_KEY"] = ""

# model2 = ChatGoogleGenerativeAI(
#     model = "gemini-2.0-flash"
# )

# %% [markdown]
# # conditional chain

# %%
from langchain_core.runnables import RunnableBranch, RunnableLambda

# %% [markdown]
# # Runnable

# %%
from langchain_core.runnables import RunnableBranch, RunnableLambda, RunnablePassthrough, RunnableSequence, RunnableParallel
